# %% [markdown]
# # Notebook 1: Download raw genomic data

# %%
# conda install ipyrad -c ipyrad

# %%
import ipyrad.analysis as ipa
import requests
import gzip
import os

# %% [markdown]
# ### Organize directory

# %%
# make a directory for storing raw data 
rawdir = os.path.realpath(os.path.join("../", "rawdata"))
if not os.path.exists(rawdir):
    os.makedirs(rawdir)
    
# and a subdirectory for storing RAD data
raddir = os.path.realpath(os.path.join(rawdir, "radseq"))
if not os.path.exists(raddir):
    os.makedirs(raddir)

# %% [markdown]
# ### Download the *Quercus robur* genome
#
# The oak genome can be downloaded from [http://www.oakgenome.fr/?page_id=587](http://www.oakgenome.fr/?page_id=587). At the time of this analysis the most recent version of the Q. robur genome is "Oak genome assembly V2_2N", which has been scaffolded into chromosomes in the version "Qrob_PM1N", which is the version we will use.

# %%
# url of fasta genome file gzipped
url = "https://urgi.versailles.inra.fr/download/oak/Qrob_PM1N.fa.gz"

# get and print location to save file
refpath = os.path.realpath(os.path.join(rawdir, url.split("/")[-1]))
refpath
# Out:
# '/home/deren/Documents/virentes-reference/rawdata/Qrob_PM1N.fa.gz'

# %%
# only run if the reference doesn't already exist
if not os.path.exists(refpath):
    
    # open a stream to url and write to file 1Mb at a time.
    res = requests.get(url, stream=True)
    with open(refpath, 'wb') as out:
        for chunk in res.iter_content(chunk_size=1024*1024):
            if chunk:
                out.write(chunk)

# %%
# make a decompressed copy of the reference file
rname = refpath.split(".gz")[0]
if not os.path.exists(rname):
    with open(rname, 'w') as out:
        out.write(gzip.open(refpath).read().decode())

# %% [markdown]
# ### Download demultiplexed RAD-seq data
#
# Sequence data are from Eaton et al. 2015. The dataset includes *Quercus* ser *Virentes* sequence reads, as well as outgroup samples. The accession number used for downloading the sra files: 'SRP055977'.

# %%
# init sra object
sra = ipa.sratools(accession="SRP055977", workdir=raddir)

# print table of runinfo columns
df = sra.fetch_runinfo(fields=(1, 4, 11, 25, 26, 28, 29, 30))
df
# Out:
# Fetching project data...
#            Run    spots Experiment     Sample     BioSample    TaxID  \
# 0   SRR1915524  4046890  SRX956496  SRS868426  SAMN03394519   168164
# 1   SRR1915538   931926  SRX956510  SRS874291  SAMN03394533  1628352
# 2   SRR1915525  5352627  SRX956497  SRS874263  SAMN03394520  1628352
# 3   SRR1915539   969575  SRX956511  SRS874290  SAMN03394534  1628352
# 4   SRR1915526  4715624  SRX956498  SRS874262  SAMN03394521  1628352
# 5   SRR1915540   817443  SRX956512  SRS874289  SAMN03394535  1628352
# 6   SRR1915541   849191  SRX956513  SRS868439  SAMN03394536   167433
# 7   SRR1915527  4539385  SRX956499  SRS874261  SAMN03394522    97695
# 8   SRR1915528  3742953  SRX956500  SRS874260  SAMN03394523   167433
# 9   SRR1915542  1012884  SRX956514  SRS874288  SAMN03394537   167433
# 10  SRR1915529  3242503  SRX956501  SRS874259  SAMN03394524   167433
# 11  SRR1915543  1204952  SRX956515  SRS874287  SAMN03394538   167433
# 12  SRR1915544   570148  SRX956516  SRS874286  SAMN03394539  1026925
# 13  SRR1915545    90661  SRX956517  SRS874284  SAMN03394540  1026925
# 14  SRR1915546   775357  SRX956518  SRS874283  SAMN03394541  1026925
# 15  SRR1915547  1130911  SRX956519  SRS874282  SAMN03394542  1026925
# 16  SRR1915530  1953553  SRX956502  SRS874258  SAMN03394525   465759
# 17  SRR1915531  3744449  SRX956503  SRS874257  SAMN03394526  1266326
# 18  SRR1915532   743556  SRX956504  SRS874256  SAMN03394527    97696
# 19  SRR1915533  3219505  SRX956505  SRS874255  SAMN03394528    97697
# 20  SRR1915548   347949  SRX956520  SRS874281  SAMN03394543    97697
# 21  SRR1915534  2826213  SRX956506  SRS874254  SAMN03394529    58333
# 22  SRR1915549   975393  SRX956521  SRS874285  SAMN03394544    58333
# 23  SRR1915550   941880  SRX956522  SRS874280  SAMN03394545    97697
# 24  SRR1915551   791393  SRX956523  SRS874279  SAMN03394546   262625
# 25  SRR1915552   905151  SRX956524  SRS874278  SAMN03394547   262625
# 26  SRR1915553  3976506  SRX956525  SRS874276  SAMN03394548   262625
# 27  SRR1915554   857771  SRX956526  SRS874275  SAMN03394549    58333
# 28  SRR1915555   908978  SRX956527  SRS874274  SAMN03394550   262625
# 29  SRR1915535  2543324  SRX956507  SRS874253  SAMN03394530    97697
# 30  SRR1915556  1115926  SRX956528  SRS874277  SAMN03394551    97697
# 31  SRR1915557  1099920  SRX956529  SRS874273  SAMN03394552    97697
# 32  SRR1915536  2777404  SRX956508  SRS874252  SAMN03394531   114190
# 33  SRR1915558  1112292  SRX956530  SRS874271  SAMN03394553   167433
# 34  SRR1915559  1436228  SRX956531  SRS874272  SAMN03394554    58333
# 35  SRR1915560  1154841  SRX956532  SRS874270  SAMN03394555   102162
# 36  SRR1915561  1347187  SRX956533  SRS874269  SAMN03394556   102162
# 37  SRR1915562  1046574  SRX956534  SRS874267  SAMN03394557   167433
# 38  SRR1915537  4482353  SRX956509  SRS874251  SAMN03394532   262615
# 39  SRR1915563   505504  SRX956535  SRS874268  SAMN03394558    58333
# 40  SRR1915564   879229  SRX956536  SRS874266  SAMN03394559   102162
# 41  SRR1915565   934386  SRX956537  SRS874264  SAMN03394560   102162
# 42  SRR1915566   163427  SRX956538  SRS874265  SAMN03394561    58333
#
#            ScientificName  SampleName
# 0       Quercus arizonica       AR_re
# 1      Quercus brandegeei     BJSB3_v
# 2      Quercus brandegeei   BJSL25_re
# 3      Quercus brandegeei    BJSL25_v
# 4      Quercus brandegeei   BJVL19_re
# 5      Quercus brandegeei    BJVL19_v
# 6        Quercus oleoides     BZBB1_v
# 7     Quercus chrysolepis       CH_re
# 8        Quercus oleoides  CRL0001_re
# 9        Quercus oleoides   CRL0001_v
# 10       Quercus oleoides  CRL0030_re
# 11       Quercus oleoides   CRL0030_v
# 12         Quercus cubana     CUCA4_v
# 13         Quercus cubana     CUMM5_v
# 14         Quercus cubana     CUSV6_v
# 15         Quercus cubana    CUVN10_v
# 16      Quercus douglasii       DO_re
# 17         Quercus durata       DU_re
# 18    Quercus engelmannii       EN_re
# 19       Quercus geminata  FLAB109_re
# 20       Quercus geminata   FLAB109_v
# 21     Quercus virginiana  FLBA140_re
# 22     Quercus virginiana   FLBA140_v
# 23       Quercus geminata    FLCK18_v
# 24         Quercus minima   FLCK216_v
# 25         Quercus minima    FLMO62_v
# 26         Quercus minima   FLSA185_v
# 27     Quercus virginiana    FLSF33_v
# 28         Quercus minima    FLSF47_v
# 29       Quercus geminata   FLSF54_re
# 30       Quercus geminata    FLSF54_v
# 31       Quercus geminata     FLWO6_v
# 32  Quercus hemisphaerica       HE_re
# 33       Quercus oleoides    HNDA09_v
# 34     Quercus virginiana     LALC2_v
# 35     Quercus fusiformis     MXED8_v
# 36     Quercus fusiformis     MXGT4_v
# 37       Quercus oleoides  MXSA3017_v
# 38          Quercus nigra       NI_re
# 39     Quercus virginiana     SCCU3_v
# 40     Quercus fusiformis     TXGR3_v
# 41     Quercus fusiformis     TXMD3_v
# 42     Quercus virginiana     TXWV2_v

# %%
# connect to parallel client started with 'ipcluster start'
import ipyparallel as ipp
ipyclient = ipp.Client()

# %%
# download the raw data files.
sra.run(name_fields=(30,1), name_separator="_", ipyclient=ipyclient)
# Out:
# [####################] 100% 0:05:39 | Downloading fastq files |  |
# 43 fastq files downloaded to /home/deren/Documents/virentes-reference/rawdata/radseq
